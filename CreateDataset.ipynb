# %%
import boto3, sagemaker
from sagemaker import get_execution_role
from IPython.display import Audio

# %%
role = get_execution_role()
region = boto3.Session().region_name
sess = sagemaker.Session()

# %%
# !jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10
# Out:
# The Jupyter HTML Notebook.
#
# This launches a Tornado based HTML Notebook Server that serves up an
# HTML5/Javascript Notebook client.
#
# Subcommands
# -----------
#
# Subcommands are launched as `jupyter-notebook cmd [args]`. For information on
# using subcommand 'cmd', do: `jupyter-notebook cmd -h`.
#
# list
#     List currently running notebook servers.
# stop
#     Stop currently running notebook server.
# password
#     Set a password for the notebook server.
#
# Options
# -------
#
# Arguments that take values are actually convenience aliases to full
# Configurables, whose aliases are listed on the help line. For more information
# on full configurables, see '--help-all'.
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
# --generate-config
#     generate default config file
# -y
#     Answer yes to any questions instead of prompting.
# --no-browser
#     Don't open the notebook in a browser after startup.
# --pylab
# ...

# %%
bucket = 'pmqd-dataset'
file_path = "Acoustic/ES_A Nightingale's Journey - Wanderer's Trove.wav"

s3_client = boto3.client('s3', aws_access_key_id='AKIAQ6MY6W3RTEQ5LTAI', aws_secret_access_key='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', region_name=region)

obj = s3_client.get_object(Bucket=bucket, Key=file_path)
print(obj)
# Out:
# {'ResponseMetadata': {'RequestId': 'FDHT9JVTD7E6RJD6', 'HostId': 'x3RYYrLR2jxadPbCgIvVVQ60xryf5hEmYb1yPMUewNLeKFv0qT/bRm74Ll73UJMyDnoT/UnEEBI=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'x3RYYrLR2jxadPbCgIvVVQ60xryf5hEmYb1yPMUewNLeKFv0qT/bRm74Ll73UJMyDnoT/UnEEBI=', 'x-amz-request-id': 'FDHT9JVTD7E6RJD6', 'date': 'Fri, 10 Dec 2021 00:00:33 GMT', 'last-modified': 'Mon, 06 Dec 2021 06:46:14 GMT', 'etag': '"ca2ecd88e66eb4b176eb06be5adb4a59-4"', 'accept-ranges': 'bytes', 'content-type': 'audio/wav', 'server': 'AmazonS3', 'content-length': '63503116'}, 'RetryAttempts': 0}, 'AcceptRanges': 'bytes', 'LastModified': datetime.datetime(2021, 12, 6, 6, 46, 14, tzinfo=tzutc()), 'ContentLength': 63503116, 'ETag': '"ca2ecd88e66eb4b176eb06be5adb4a59-4"', 'ContentType': 'audio/wav', 'Metadata': {}, 'Body': <botocore.response.StreamingBody object at 0x7f1fe469cc50>}

# %%
bucket = 'pmqd-dataset'
subfolder = ''
from sagemaker import get_execution_role
role = get_execution_role()

# %%
import boto3

# When running on SageMaker, need execution role
from sagemaker import get_execution_role
role = get_execution_role()

# Declare bucket name, remote file, and destination

dest_file = "a.wav"

# Connect to S3 bucket and download file
s3 = boto3.resource('s3', aws_access_key_id='AKIAQ6MY6W3RTEQ5LTAI', aws_secret_access_key='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', region_name=region)



conn = boto3.client('s3')
contents = conn.list_objects(Bucket=bucket, Prefix=subfolder)['Contents']
i = 0
for f in contents:
    s3.Bucket(my_bucket).download_file(f['Key'], "Dataset/" + str(i) + ".wav")
    i += 1

# %%
# %pip install pydub
from pydub import AudioSegment
t1 = 0 #Works in milliseconds
t2 = 4000
for i in range(0, 650):
    for e in range(3):
        print("file"+ str(i) +'_'+ str(e))
        t1 = 0 + e*10000
        t2 = 4000 + e*10000
        newAudio = AudioSegment.from_wav("Dataset/" + str(i) + ".wav")
        newAudio = newAudio[t1:t2]
        newAudio.export('data_segments/' + str(i) +'_'+ str(e) +'.wav', format="wav")
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# file51_0
# file51_1
# file51_2
# file52_0
# file52_1
# file52_2
# file53_0
# file53_1
# file53_2
# file54_0
# file54_1
# file54_2
# file55_0
# file55_1
# file55_2
# file56_0
# file56_1
# file56_2
# file57_0
# file57_1
# file57_2
# file58_0
# file58_1
# file58_2
# file59_0
# file59_1
# file59_2
